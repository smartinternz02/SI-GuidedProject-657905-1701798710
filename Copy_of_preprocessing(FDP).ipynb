# %%
from google.colab import files

# Upload the Kaggle API token
files.upload()
# Out:
#      <input type="file" id="files-1fc94103-8a47-4b93-b6b1-f939435ca56d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fc94103-8a47-4b93-b6b1-f939435ca56d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tanlikesmath/diabetic-retinopathy-resized
# Out:
# ...
# 100% 7.25G/7.25G [01:05<00:00, 146MB/s]
# 100% 7.25G/7.25G [01:05<00:00, 119MB/s]

# %%
# !unzip diabetic-retinopathy-resized.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: resized_train_cropped/resized_train_cropped/44260_right.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44261_left.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44261_right.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44262_left.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44262_right.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44263_left.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44263_right.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44264_left.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44264_right.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44265_left.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44265_right.jpeg
#   inflating: resized_train_cropped/resized_train_cropped/44267_left.jpeg
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/trainLabels.csv)')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-c365cc470eef> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/trainLabels.csv)')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df = pd.read_csv('/content/trainLabels_cropped.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     image  level
# 0             0           0   10_left      0
# 1             1           1  10_right      0
# 2             2           2   13_left      0
# 3             3           3  13_right      0
# 4             4           4   15_left      1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0.1'].plot(kind='hist', bins=20, title='Unnamed: 0.1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['level'].plot(kind='hist', bins=20, title='level')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# ...

# %%
df.isnull()
# Out:
#        Unnamed: 0.1  Unnamed: 0  image  level
# 0             False       False  False  False
# 1             False       False  False  False
# 2             False       False  False  False
# 3             False       False  False  False
# 4             False       False  False  False
# ...             ...         ...    ...    ...
# 35103         False       False  False  False
# 35104         False       False  False  False
# 35105         False       False  False  False
# 35106         False       False  False  False
# 35107         False       False  False  False
#
# [35108 rows x 4 columns]
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# image           0
# level           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35108 entries, 0 to 35107
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  35108 non-null  int64
#  1   Unnamed: 0    35108 non-null  int64
#  2   image         35108 non-null  object
#  3   level         35108 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.1+ MB

# %%
imagesize = [299,299]
testpath = r"/content/preprocessed dataset/testing"
trainpath = r"/content/preprocessed dataset/training"

# %%
pip install tensorflow

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras.layers import Dense,Flatten,Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.applications.xception import xception,preprocess_input
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-21bd8d7b2e44> in <cell line: 5>()
#       3 from tensorflow.keras.preprocessing import image
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
# ----> 5 from tensorflow.keras.applications.xception import xception,preprocess_input
#       6 from glob import glob
#       7 import numpy as np
#
# ImportError: cannot import name 'xception' from 'tensorflow.keras.applications.xception' (/usr/local/lib/python3.10/dist-packages/keras/api/_v2/keras/applications/xception/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
from tensorflow.keras.applications import Xception

# %%
from tensorflow.keras.layers import Dense,Flatten,Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.applications.xception import xception,preprocess_input
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-21bd8d7b2e44> in <cell line: 5>()
#       3 from tensorflow.keras.preprocessing import image
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
# ----> 5 from tensorflow.keras.applications.xception import xception,preprocess_input
#       6 from glob import glob
#       7 import numpy as np
#
# ImportError: cannot import name 'xception' from 'tensorflow.keras.applications.xception' (/usr/local/lib/python3.10/dist-packages/keras/api/_v2/keras/applications/xception/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
from tensorflow.keras.layers import Dense,Flatten,Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.applications.xception import Xception, preprocess_input
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale = 1./255)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7f976ab01502> in <cell line: 1>()
# ----> 1 train_datagen = ImageDataGenerator(rescale = 1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
#       2 test_datagen = ImageDataGenerator(rescale = 1./255)
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
# Import necessary modules
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create instances of ImageDataGenerator for training and testing data
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(r"/content/preprocessed dataset/training",target_size=(299,299),batch_size=32,class_mode='categorical')
test_set = test_datagen.flow_from_directory(r"/content/preprocessed dataset/testing",target_size=(299,299),batch_size=32,class_mode='categorical')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-44a3ba69ac82> in <cell line: 1>()
# ----> 1 training_set = train_datagen.flow_from_directory(r"/content/preprocessed dataset/training",target_size=(299,299),batch_size=32,class_mode='categorical')
#       2 test_set = test_datagen.flow_from_directory(r"/content/preprocessed dataset/testing",target_size=(299,299),batch_size=32,class_mode='categorical')
#       3
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1647             and `y` is a numpy array of corresponding labels.
#    1648         """
# -> 1649         return DirectoryIterator(
#    1650             directory,
# ...

# %%
training_set = train_datagen.flow_from_directory(r"/content/preprocessed dataset/training",target_size=(299,299),batch_size=32,class_mode='categorical')
test_set = test_datagen.flow_from_directory(r"/content/preprocessed dataset/testing",target_size=(299,299),batch_size=32,class_mode='categorical')
# Out:
# Found 0 images belonging to 0 classes.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-2df2611c10dc> in <cell line: 2>()
#       1 training_set = train_datagen.flow_from_directory(r"/content/preprocessed dataset/training",target_size=(299,299),batch_size=32,class_mode='categorical')
# ----> 2 test_set = test_datagen.flow_from_directory(r"/content/preprocessed dataset/testing",target_size=(299,299),batch_size=32,class_mode='categorical')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1647             and `y` is a numpy array of corresponding labels.
#    1648         """
# -> 1649         return DirectoryIterator(
# ...

# %%
import os

training_dir = r"/content/preprocessed dataset/training"
print(os.path.exists(training_dir))
# Out:
# False

# %%
import os

# Specify the directory path
training_dir = r"/content/preprocessed dataset/training"

# Check if the directory exists, and create it if it doesn't
if not os.path.exists(training_dir):
    os.makedirs(training_dir)
    print(f"Directory '{training_dir}' created.")
else:
    print(f"Directory '{training_dir}' already exists.")
# Out:
# Directory '/content/preprocessed dataset/training' created.

# %%
import os

# Specify the directory path
training_dir = r"/content/preprocessed dataset/testing"

# Check if the directory exists, and create it if it doesn't
if not os.path.exists(testing_dir):
    os.makedirs(testing_dir)
    print(f"Directory '{testing_dir}' created.")
else:
    print(f"Directory '{testing_dir}' already exists.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0574c3f32a98> in <cell line: 7>()
#       5
#       6 # Check if the directory exists, and create it if it doesn't
# ----> 7 if not os.path.exists(testing_dir):
#       8     os.makedirs(testing_dir)
#       9     print(f"Directory '{testing_dir}' created.")
#
# NameError: name 'testing_dir' is not defined

# %%
import os

# Specify the testing directory path
testing_dir = r"/content/preprocessed dataset/testing"

# Check if the directory exists, and create it if it doesn't
if not os.path.exists(testing_dir):
    os.makedirs(testing_dir)
    print(f"Directory '{testing_dir}' created.")
else:
    print(f"Directory '{testing_dir}' already exists.")
# Out:
# Directory '/content/preprocessed dataset/testing' created.
